# %%
# !pip install torch_geometric
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.5.3-py3-none-any.whl.metadata (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.66.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.13.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2024.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.10.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.3.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2024.7.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (3.5.0)
# Downloading torch_geometric-2.5.3-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.5 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.5.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/fault_loc_dataset/fault_loc_dataset.csv')

# %%
base_dir = "/content/drive/MyDrive/fault_loc_dataset/"

# %%
df['full_path'] = base_dir + df['Filename']

# %%
all_buggy_files = df[df['buggy'] == True]['full_path'].tolist()
all_right_models = df[df['buggy'] == False]['full_path'].tolist()

# %%
import ast

model_code = """
model = Sequential()
model.add(GRU(256 , return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(256))
model.add(Dropout(0.4))
model.add(Dense(64 ,  activation = 'relu'))
model.add(Dense(1))

"""

# Define default values for variables
default_values = {
    'vocab_size': 10000,
    'embedding_dim': 100,
    'max_length': 80,
    'gru_dim': 64,
    'dense_dim': 32,
    'max_features': 10000
}

# Define default attributes for different layer types
default_attributes = {
    'Embedding': {
        'input_dim': None,
        'output_dim': None,
        'input_length': None
    },
    'GRU': {
        'units': None,
        'activation': 'tanh',
        'recurrent_activation': 'sigmoid',
        'use_bias': True,
        'kernel_initializer': 'glorot_uniform',
        'recurrent_initializer': 'orthogonal',
        'bias_initializer': 'zeros',
        'unit_forget_bias': True,
        'kernel_regularizer': None,
        'recurrent_regularizer': None,
        'bias_regularizer': None,
        'activity_regularizer': None,
        'kernel_constraint': None,
        'recurrent_constraint': None,
        'bias_constraint': None,
        'dropout': 0.0,
        'recurrent_dropout': 0.0,
        'implementation': 1,
        'return_sequences': False,
        'return_state': False,
        'go_backwards': False,
        'stateful': False,
        'unroll': False,
        'time_major': False,
        'reset_after': True
    },
    'Dense': {
        'units': None,
        'activation': None,
        'use_bias': True,
        'kernel_initializer': 'glorot_uniform',
        'bias_initializer': 'zeros',
        'kernel_regularizer': None,
        'bias_regularizer': None,
        'activity_regularizer': None,
        'kernel_constraint': None,
        'bias_constraint': None,
        'lora_rank': None
    },
    'Dropout': {
        'rate': None,
        'noise_shape': None,
        'seed': None
    },
    'LSTM': {
        'units': None,
        'activation': 'tanh',
        'recurrent_activation': 'sigmoid',
        'use_bias': True,
        'kernel_initializer': 'glorot_uniform',
        'recurrent_initializer': 'orthogonal',
        'bias_initializer': 'zeros',
        'unit_forget_bias': True,
        'kernel_regularizer': None,
        'recurrent_regularizer': None,
        'bias_regularizer': None,
        'activity_regularizer': None,
        'kernel_constraint': None,
        'recurrent_constraint': None,
        'bias_constraint': None,
        'dropout': 0.0,
        'recurrent_dropout': 0.0,
        'implementation': 2,
        'return_sequences': False,
        'return_state': False,
        'go_backwards': False,
        'stateful': False,
        'unroll': False,
        'time_major': False
    },
    'Conv2D': {
        'filters': None,
        'kernel_size': None,
        'strides': (1, 1),
        'padding': 'valid',
        'data_format': None,
        'dilation_rate': (1, 1),
        'activation': None,
        'use_bias': True,
        'kernel_initializer': 'glorot_uniform',
        'bias_initializer': 'zeros',
        'kernel_regularizer': None,
        'bias_regularizer': None,
        'activity_regularizer': None,
        'kernel_constraint': None,
        'bias_constraint': None
    },
    'Conv1D': {
        'filters': None,
        'kernel_size': None,
        'strides': 1,
        'padding': 'valid',
        'data_format': None,
        'dilation_rate': 1,
        'activation': None,
        'use_bias': True,
        'kernel_initializer': 'glorot_uniform',
        'bias_initializer': 'zeros',
        'kernel_regularizer': None,
        'bias_regularizer': None,
        'activity_regularizer': None,
        'kernel_constraint': None,
        'bias_constraint': None
    },
    'MaxPooling2D': {
        'pool_size': (2, 2),
        'strides': None,
        'padding': 'valid',
        'data_format': None
    },
    'MaxPooling1D': {
        'pool_size': 2,
        'strides': None,
        'padding': 'valid'
    },
    'Flatten': {}
}

class ModelGraphBuilder(ast.NodeVisitor):
    def __init__(self):
        self.graph = []

    def visit_Call(self, node):
        if isinstance(node.func, ast.Attribute) and node.func.attr == 'add':
            layer = node.args[0]
            if isinstance(layer.func, ast.Name) and layer.func.id == 'Bidirectional':
                wrapped_layer = layer.args[0]
                self.add_layer(wrapped_layer, bidirectional=True)
            else:
                self.add_layer(layer)
        self.generic_visit(node)

    def get_value(self, node):
        if isinstance(node, ast.Name):
            return default_values.get(node.id, node.id)
        return ast.literal_eval(node)

    def get_layer_type(self, layer_func):
        if isinstance(layer_func, ast.Attribute):
            return layer_func.attr
        elif isinstance(layer_func, ast.Name):
            return layer_func.id
        return None

    def add_layer(self, layer, bidirectional=False):
        layer_type = self.get_layer_type(layer.func)
        if layer_type is None:
            return

        layer_attributes = default_attributes.get(layer_type, {}).copy()

        # Handle positional arguments
        for i, arg in enumerate(layer.args):
            keys = list(layer_attributes.keys())
            if i < len(keys):
                layer_attributes[keys[i]] = self.get_value(arg)

        # Handle keyword arguments
        for kw in layer.keywords:
            layer_attributes[kw.arg] = self.get_value(kw.value)

        if bidirectional:
            self.graph.append((f'Bidirectional_{layer_type}_forward', layer_attributes.copy()))
            self.graph.append((f'Bidirectional_{layer_type}_backward', layer_attributes.copy()))
        else:
            self.graph.append((layer_type, layer_attributes))

# Parse the code
tree = ast.parse(model_code)

# Build the graph
builder = ModelGraphBuilder()
builder.visit(tree)

# Print the graph with default attributes
for node in builder.graph:
    print(node)
# Out:
# ('GRU', {'units': 256, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': 'glorot_uniform', 'recurrent_initializer': 'orthogonal', 'bias_initializer': 'zeros', 'unit_forget_bias': True, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 1, 'return_sequences': True, 'return_state': False, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'reset_after': True})
# ('Dropout', {'rate': 0.4, 'noise_shape': None, 'seed': None})
# ('LSTM', {'units': 256, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': 'glorot_uniform', 'recurrent_initializer': 'orthogonal', 'bias_initializer': 'zeros', 'unit_forget_bias': True, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2, 'return_sequences': False, 'return_state': False, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False})
# ('Dropout', {'rate': 0.4, 'noise_shape': None, 'seed': None})
# ('Dense', {'units': 64, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': 'glorot_uniform', 'bias_initializer': 'zeros', 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None, 'lora_rank': None})
# ('Dense', {'units': 1, 'activation': None, 'use_bias': True, 'kernel_initializer': 'glorot_uniform', 'bias_initializer': 'zeros', 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None, 'lora_rank': None})

# %%
from tqdm import tqdm
all_right_graphs = []
all_right_labels = []
for path in tqdm(all_right_models):
    with open(path, 'r') as file:
        content = file.read()
    try:
        # Parse the code
        tree = ast.parse(content)

        # Build the graph
        builder = ModelGraphBuilder()
        builder.visit(tree)
        all_right_graphs.append(builder.graph)
        all_right_labels.append(0)
    except Exception as e:
        print(f"Error parsing file {path}: {e}")

all_fault_graphs = []
all_fault_labels = []
for path in tqdm(all_buggy_files):
    with open(path, 'r') as file:
        content = file.read()
        label = path.split('/')[-1].split('.')[0].split('_')[1]
        label = 'b1' if label in ['b10', 'b11', 'b12', 'b13', 'b14', 'b15', 'b16', 'b17', 'b18', 'b19'] else label
        label = label.replace('b', '')
        label = int(label)
    try:
        # Parse the code
        tree = ast.parse(content)

        # Build the graph
        builder = ModelGraphBuilder()
        builder.visit(tree)
        all_fault_graphs.append(builder.graph)
        all_fault_labels.append(label)

    except Exception as e:
        print(f"Error parsing file {path}: {e}")
# Out:
# 100%|██████████| 38/38 [00:38<00:00,  1.01s/it]
#   3%|▎         | 48/1593 [00:00<00:10, 153.43it/s]
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b3_5.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6e1d0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b10.py: malformed node or string on line 3: <ast.BinOp object at 0x7e24c0f23310>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b18.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0c6dae0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b2_6.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0f23880>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b2_2.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0dfb490>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b2_3.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0c6c040>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b2_5.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0f23df0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b2_9.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0dfb580>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b2_1.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0c68220>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b3_0.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0f238e0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b2_7.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0dfbc40>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b2_8.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0c6dc00>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b3_2.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0f23df0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b3_1.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0dfb670>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_1.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0c6e740>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_0.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0f23a30>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_3.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0dfada0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_5.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0c6f4f0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b3_3.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0f22e30>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_4.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0dfbb80>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b3_4.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0c6b010>
#   4%|▍         | 68/1593 [00:00<00:08, 169.65it/s]
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_2.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0f23a30>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_6.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0c6d9c0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_8.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0c6b8b0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_9.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0dfb490>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_7.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0c6b130>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_14.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0c6d180>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_11.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0dfb5b0>
#   5%|▌         | 85/1593 [00:00<00:17, 84.42it/s]
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_10.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0c69e70>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_13.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0c6c790>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_12.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0dfa620>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU7_b4_15.py: malformed node or string on line 3: <ast.Name object at 0x7e24c0c6fe20>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b1_0.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6ef20>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b1_5.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6e320>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b1_1.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6c190>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b1_4.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6ca60>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b1_2.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6cac0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b1_6.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6d810>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b1_3.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6d870>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b1_7.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6cdc0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b2_2.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6e1d0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b1_8.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6dab0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b2_3.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6f070>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b2_1.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6efb0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b1_9.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0dfba60>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b2_6.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0f23b20>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b2_0.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6d3c0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b2_5.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6caf0>
#   7%|▋         | 116/1593 [00:01<00:14, 105.33it/s]
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b2_7.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6fc70>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b2_4.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6f460>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b2_8.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6c1f0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b2_9.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6c070>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b3_2.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6d120>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b3_1.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6d3c0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b3_0.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6d360>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b3_6.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c689a0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b3_5.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c69f60>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b3_4.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c685e0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b3_3.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6b6d0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b3_7.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c69b10>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_0.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c69180>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_1.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6f040>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_2.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c68580>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_4.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c688b0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_5.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6bbb0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_3.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6f190>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_6.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6d570>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_7.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6ebf0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_8.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6f910>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_9.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6e4a0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_10.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6f730>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_11.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6f250>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_14.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6c2b0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_12.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6d870>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_13.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6d570>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU6_b4_15.py: malformed node or string on line 4: <ast.Call object at 0x7e24c0c6e2f0>
#  18%|█▊        | 292/1593 [00:01<00:05, 228.15it/s]
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b1_2_0.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6c8b0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b1_2_1.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6f910>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b1_2_2.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6f5b0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b1_2_3.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6d480>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b1_2_4.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6e770>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b1_2_5.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6f1c0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b1_2_6.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6e6e0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b1_2_7.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6cb20>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b1_2_8.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6e830>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b1_2_9.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6e770>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b3_2_0.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6f1c0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b3_2_1.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6cac0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b3_2_2.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6e260>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b3_2_3.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6e110>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b3_2_4.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6ef20>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b3_2_5.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6ca00>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b3_2_6.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6c9a0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b3_2_7.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6f340>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_0.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6cac0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_1.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6b340>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_2.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6d240>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_3.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6b8e0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_4.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c698d0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_5.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6cac0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_6.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6aef0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_7.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c69540>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_8.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6e770>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_9.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c68e20>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_10.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6a7a0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_11.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0df9720>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_12.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6d240>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_13.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0dfb640>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_14.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0c6b5e0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b4_2_15.py: malformed node or string on line 4: <ast.Name object at 0x7e24c0dfbc70>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b1_3_0.py: unexpected indent (<unknown>, line 12)
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b1_3_1.py: unexpected indent (<unknown>, line 12)
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b1_3_2.py: unexpected indent (<unknown>, line 12)
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/RNN4_b1_3
py: malformed node or string on line 8: <ast.Call object at 0x7e24c035ba30>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM8_b4_2.py: malformed node or string on line 8: <ast.Call object at 0x7e24c035b580>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM8_b4_1.py: malformed node or string on line 8: <ast.Call object at 0x7e24c0359120>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM8_b4_0.py: malformed node or string on line 8: <ast.Call object at 0x7e24c035a740>
#  84%|████████▎ | 1332/1593 [00:10<00:01, 196.59it/s]
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b1_0.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0f23eb0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b1_1.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0dfa200>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b1_2.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0df9b40>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b1_3.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0f23400>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b1_4.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0df9ba0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b1_5.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c6beb0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b1_6.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0f23fa0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b1_7.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c6be50>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b2_1.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c685e0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b2_2.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0dfb3d0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b2_3.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c69000>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b2_4.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c6b4f0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b2_5.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0dfba00>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b2_6.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c6ac50>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b2_7.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0dfb790>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b2_8.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c6bf40>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b2_9.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0dfbca0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b2_10.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c6a4a0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b3_0.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c6bd60>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b3_1.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c6bb50>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b3_2.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c68280>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b3_4.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c696f0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b3_3.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c685e0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b3_5.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c69000>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b3_6.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c6b820>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b3_7.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c6bb50>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b3_8.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c6bac0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b3_9.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0dfab60>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b3_10.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0df9600>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b3_11.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0359510>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b3_12.py: malformed node or string on line 2: <ast.Name object at 0x7e24c035a110>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b3_14.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0359f90>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b1_14.py: malformed node or string on line 2: <ast.Name object at 0x7e24c035a830>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b1_13.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0358cd0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b1_12.py: malformed node or string on line 2: <ast.Name object at 0x7e24c035a9e0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b1_11.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0358430>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b1_10.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c69f00>
#  86%|████████▋ | 1376/1593 [00:10<00:01, 207.45it/s]
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b1_9.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0358a90>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/LSTM10_b1_8.py: malformed node or string on line 2: <ast.Name object at 0x7e24c0c69f00>
#  93%|█████████▎| 1482/1593 [00:10<00:00, 202.65it/s]
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_0.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0359240>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_1.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0358c10>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_2.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0358f40>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_3.py: malformed node or string on line 6: <ast.Call object at 0x7e24c035ac20>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_4.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0359d80>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_5.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0dfb790>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_6.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0c6ad10>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_7.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0c6ae00>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_8.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0c68c70>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_9.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0c69a80>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_10.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0358370>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_11.py: malformed node or string on line 6: <ast.Call object at 0x7e24c035bb20>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_12.py: malformed node or string on line 6: <ast.Call object at 0x7e24c035aaa0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_13.py: malformed node or string on line 6: <ast.Call object at 0x7e24c035b490>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_14.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0359a80>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_15.py: malformed node or string on line 6: <ast.Call object at 0x7e24c035b3d0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_17.py: malformed node or string on line 6: <ast.Call object at 0x7e24c035a020>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_18.py: malformed node or string on line 6: <ast.Call object at 0x7e24c035bfa0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b1_19.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0358f70>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b2_1.py: malformed node or string on line 6: <ast.Call object at 0x7e24c035bc40>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b2_2.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0c6b220>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b2_3.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0c68790>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b2_4.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0c6bc70>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b2_5.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0c6a470>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b2_6.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0dfbbe0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b2_7.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0c68ca0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b2_8.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0c6b4f0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b2_9.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0c68430>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b2_10.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0c68700>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b3_1.py: malformed node or string on line 6: <ast.Call object at 0x7e24c035b8e0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b3_2.py: malformed node or string on line 6: <ast.Call object at 0x7e24c035a500>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b3_3.py: malformed node or string on line 6: <ast.Call object at 0x7e24c03591e0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b3_4.py: malformed node or string on line 6: <ast.Call object at 0x7e24c03598d0>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b3_5.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0359f30>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b3_6.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0f23460>
# Error parsing file /content/drive/MyDrive/fault_loc_dataset/GRU5_b3_7.py: malformed node or string on line 6: <ast.Call object at 0x7e24c0359b10>
# 100%|██████████| 1593/1593 [00:11<00:00, 141.63it/s]

# %%
all_right_labels = [0] * len(all_right_graphs)
all_fault_labels = [1] * len(all_fault_graphs)

# %%
all_class_labels = all_right_labels + all_fault_labels

# %%
all_graphs = all_right_graphs + all_fault_graphs
all_labels = all_right_labels + all_fault_labels

# %%
len(all_graphs), len(all_labels), len(all_class_labels)
# Out:
# (1281, 1281, 1281)

# %%
from sklearn.utils import resample
from collections import Counter

def balance_dataset(graphs, labels):
    """
    Balances the dataset by oversampling the minority class or undersampling the majority class.

    Args:
        graphs (list): List of graphs.
        labels (list): List of labels corresponding to the graphs.

    Returns:
        balanced_graphs (list): Balanced list of graphs.
        balanced_labels (list): Balanced list of labels.
    """
    # Separate by class
    class_indices = {}
    for index, label in enumerate(labels):
        if label not in class_indices:
            class_indices[label] = []
        class_indices[label].append(index)

    # Determine the maximum class size
    max_count = max(len(indices) for indices in class_indices.values())

    balanced_graphs = []
    balanced_labels = []

    for label, indices in class_indices.items():
        class_graphs = [graphs[i] for i in indices]
        class_labels = [labels[i] for i in indices]

        # Oversample minority class
        if len(class_graphs) < max_count:
            class_graphs_oversampled, class_labels_oversampled = resample(
                class_graphs,
                class_labels,
                replace=True,
                n_samples=max_count,
                random_state=42
            )
            balanced_graphs.extend(class_graphs_oversampled)
            balanced_labels.extend(class_labels_oversampled)
        else:
            balanced_graphs.extend(class_graphs)
            balanced_labels.extend(class_labels)

    return balanced_graphs, balanced_labels

# Example usage
balanced_graphs, balanced_labels = balance_dataset(all_graphs, all_class_labels)

# Now you can proceed with further processing or batching

# %%
len(balanced_labels)
# Out:
# 2486

# %%
import numpy as np
from sklearn.preprocessing import OneHotEncoder
import torch
from torch_geometric.data import Data, Batch

def preprocess_graphs(graphs, labels, possible_activations):
    """
    Preprocesses multiple graphs into node features and edge index for GNN input.

    Args:
        graphs (list of list): List of graphs, where each graph is a list of tuples (layer, attributes).
        labels (list): List of labels corresponding to each graph.
        possible_activations (list): List of possible activation functions for one-hot encoding.

    Returns:
        Batch: PyTorch Geometric Batch object containing all processed graphs.
    """
    encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
    try:
        encoder.fit(np.array(possible_activations).reshape(-1, 1))
    except Exception as e:
        print(f"Error fitting encoder: {e}")
        raise

    # Attributes to keep
    attributes_to_keep = [
        'units', 'activation', 'recurrent_activation', 'kernel_regularizer', 'recurrent_regularizer',
        'bias_regularizer', 'activity_regularizer', 'recurrent_dropout', 'dropout'
    ]

    data_list = []
    max_node_feature_length = 0

    for graph_index, (graph, label) in enumerate(zip(graphs, labels)):
        node_features = []
        edge_index = []

        try:
            for layer, attributes in graph:
                encoded_attributes = {}

                if 'activation' in attributes:
                    activation = attributes.get('activation', 'None')
                    if activation not in possible_activations:
                        print(f"Warning: Activation function '{activation}' not in possible_activations")
                        activation = 'None'
                    encoded_activation = encoder.transform([[activation]]).flatten().tolist()
                    encoded_attributes['activation'] = encoded_activation

                if 'recurrent_activation' in attributes:
                    recurrent_activation = attributes.get('recurrent_activation', 'None')
                    if recurrent_activation not in possible_activations:
                        print(f"Warning: Recurrent activation function '{recurrent_activation}' not in possible_activations")
                        recurrent_activation = 'None'
                    encoded_recurrent_activation = encoder.transform([[recurrent_activation]]).flatten().tolist()
                    encoded_attributes['recurrent_activation'] = encoded_recurrent_activation

                for key in attributes_to_keep:
                    if key in attributes and key not in ['activation', 'recurrent_activation']:
                        value = attributes.get(key, 0)
                        if value is None:
                            value = 0
                        encoded_attributes[key] = value

                combined_features = []
                if 'activation' in encoded_attributes:
                    combined_features.extend(encoded_attributes['activation'])
                if 'recurrent_activation' in encoded_attributes:
                    combined_features.extend(encoded_attributes['recurrent_activation'])

                for key in attributes_to_keep:
                    if key in encoded_attributes and key not in ['activation', 'recurrent_activation']:
                        combined_features.append(encoded_attributes[key])

                node_features.append(combined_features)
                max_node_feature_length = max(max_node_feature_length, len(combined_features))

            if not node_features:
                print(f"Warning: Skipping empty node_features for graph {graph_index}")
                continue

            # Ensure all node features have the same length
            node_features = [f + [0] * (max_node_feature_length - len(f)) for f in node_features]
            node_features = np.array(node_features, dtype=float)
            x = torch.tensor(node_features, dtype=torch.float)

            # Create edge index
            num_nodes = len(node_features)
            if num_nodes > 1:
                edge_index = torch.tensor(
                    [[i, i + 1] for i in range(num_nodes - 1)] +
                    [[i + 1, i] for i in range(num_nodes - 1)], dtype=torch.long
                ).t().contiguous()
            else:
                edge_index = torch.empty((2, 0), dtype=torch.long)  # Empty edge_index for single-node graphs

            # Convert label to tensor
            y = torch.tensor([label], dtype=torch.long)

            data = Data(x=x, edge_index=edge_index, y=y)
            data_list.append(data)

        except Exception as e:
            print(f"Error processing graph {graph_index}: {e}")
            continue

    try:
        if not data_list:
            print("Warning: No valid graphs to create a batch.")
            return None

        # Create batch from list of graphs
        batch = Batch.from_data_list(data_list)

        # Debugging: Print shapes of tensors in data_list
        for i, data in enumerate(data_list):
            print(f"Graph {i} - x shape: {data.x.shape}, edge_index shape: {data.edge_index.shape}")

    except Exception as e:
        print(f"Error creating batch: {e}")
        raise

    return batch

# %%
import torch.optim as optim

def train_model(model, data, epochs=200, lr=0.01, weight_decay=5e-4):
    """
    Trains the GNN model on the given graph data.

    Args:
        model (torch.nn.Module): The GNN model.
        data (Batch): The batched graph data.
        epochs (int): Number of training epochs.
        lr (float): Learning rate.
        weight_decay (float): Weight decay for optimizer.
    """
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()
        out = model(data)
        loss = F.nll_loss(out, data.y)
        loss.backward()
        optimizer.step()

        if epoch % 10 == 0:
            acc = test_model(model, data)
            print(f'Epoch: {epoch}, Loss: {loss:.4f}, Accuracy: {acc:.4f}')

def test_model(model, data):
    """
    Evaluates the GNN model on the given graph data.

    Args:
        model (torch.nn.Module): The GNN model.
        data (Batch): The batched graph data.

    Returns:
        float: Accuracy of the model on the data.
    """
    model.eval()
    _, pred = model(data).max(dim=1)
    correct = float(pred.eq(data.y).sum().item())
    return correct / len(data.y)  # Number of graphs

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool

class GNN(torch.nn.Module):
    def __init__(self, num_node_features):
        super(GNN, self).__init__()
        self.conv1 = GCNConv(num_node_features, 16)
        self.conv2 = GCNConv(16, 16)
        self.conv3 = GCNConv(16, 16)
        self.fc = torch.nn.Linear(16, 2)  # Binary classification (2 classes)

    def forward(self, batch):
        x, edge_index, batch = batch.x, batch.edge_index, batch.batch

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.conv3(x, edge_index)
        x = F.relu(x)

        # Global mean pooling
        x = global_mean_pool(x, batch)

        # Final dense layer for classification
        x = self.fc(x)

        return F.log_softmax(x, dim=1)

# %%
# Define the possible activations
possible_activations = [ None,
    'relu', 'sigmoid', 'tanh', 'softmax', 'softplus', 'softsign',
    'selu', 'elu', 'exponential', 'linear', 'None',
 'gelu', 'selu', 'softmax', 'softplus', 'softsign',               'leaky_relu', 'silu', 'hard_silu', 'mish',
                         'hard_sigmoid', 'relu6'
]


# Prepare data
batch = preprocess_graphs(balanced_graphs, balanced_labels, possible_activations)
# Out:
# Warning: Skipping empty node_features for graph 1963
# Error processing graph 2075: could not convert string to float: 'relu'
# Graph 0 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 1 - x shape: torch.Size([21, 45]), edge_index shape: torch.Size([2, 40])
# Graph 2 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 3 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 4 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 5 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 6 - x shape: torch.Size([17, 45]), edge_index shape: torch.Size([2, 32])
# Graph 7 - x shape: torch.Size([17, 45]), edge_index shape: torch.Size([2, 32])
# Graph 8 - x shape: torch.Size([7, 45]), edge_index shape: torch.Size([2, 12])
# Graph 9 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 10 - x shape: torch.Size([7, 45]), edge_index shape: torch.Size([2, 12])
# Graph 11 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 12 - x shape: torch.Size([13, 45]), edge_index shape: torch.Size([2, 24])
# Graph 13 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 14 - x shape: torch.Size([7, 45]), edge_index shape: torch.Size([2, 12])
# Graph 15 - x shape: torch.Size([7, 45]), edge_index shape: torch.Size([2, 12])
# Graph 16 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 17 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph
- x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 409 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 410 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 411 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 412 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 413 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 414 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 415 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 416 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 417 - x shape: torch.Size([17, 45]), edge_index shape: torch.Size([2, 32])
# Graph 418 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 419 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 420 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 421 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 422 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 423 - x shape: torch.Size([14, 45]), edge_index shape: torch.Size([2, 26])
# Graph 424 - x shape: torch.Size([7, 45]), edge_index shape: torch.Size([2, 12])
# Graph 425 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 426 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 427 - x shape: torch.Size([7, 45]), edge_index shape: torch.Size([2, 12])
# Graph 428 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 429 - x shape: torch.Size([7, 45]), edge_index shape: torch.Size([2, 12])
# Graph 430 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 431 - x shape: torch.Size([13, 45]), edge_index shape: torch.Size([2, 24])
# Graph 432 - x shape: torch.Size([12, 45]), edge_index shape: torch.Size([2, 22])
# Graph 433 - x shape: torch.Size([17, 45]), edge_index shape: torch.Size([2, 32])
# Graph 434 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 435 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 436 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 437 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 438 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 439 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 440 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 441 - x shape: torch.Size([25, 45]), edge_index shape: torch.Size([2, 48])
# Graph 442 - x shape: torch.Size([7, 45]), edge_index shape: torch.Size([2, 12])
# Graph 443 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 444 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 445 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 446 - x shape: torch.Size([19, 45]), edge_index shape: torch.Size([2, 36])
# Graph 447 - x shape: torch.Size([9, 45]), edge_index shape: torch.Size([2, 16])
# Graph 448 - x shape: torch.Size([7, 45]), edge_index shape: torch.Size([2, 12])
# Graph 449 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 450 - x shape: torch.Size([9, 45]), edge_index shape: torch.Size([2, 16])
# Graph 451 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 452 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 453 - x shape: torch.Size([17, 45]), edge_index shape: torch.Size([2, 32])
# Graph 454 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 455 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 456 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 457 - x shape: torch.Size([7, 45]), edge_index shape: torch.Size([2, 12])
# Graph 458 - x shape: torch.Size([14, 45]), edge_index shape: torch.Size([2, 26])
# Graph 459 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 460 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 461 - x shape: torch.Size([13, 45]), edge_index shape: torch.Size([2, 24])
# Graph 462 - x shape: torch.Size([17, 45]), edge_index shape: torch.Size([2, 32])
# Graph 463 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 464 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 465 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 466 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 467 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 468 - x shape: torch.Size([25, 45]), edge_index shape: torch.Size([2, 48])
# Graph 469 - x shape: torch.Size([13, 45]), edge_index shape: torch.Size([2, 24])
# Graph 470 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 471 - x shape: torch.Size([19, 45]), edge_index shape: torch.Size([2, 36])
# Graph 472 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 473 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 474 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 475 - x shape: torch.Size([14, 45]), edge_index shape: torch.Size([2, 26])
# Graph 476 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 477 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 478 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 479 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 480 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 481 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 482 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 483 - x shape: torch.Size([19, 45]), edge_index shape: torch.Size([2, 36])
# Graph 484 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 485 - x shape: torch.Size([14, 45]), edge_index shape: torch.Size([2, 26])
# Graph 486 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 487 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 488 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 489 - x shape: torch.Size([17, 45]), edge_index shape: torch.Size([2, 32])
# Graph 490 - x shape: torch.Size([19, 45]), edge_index shape: torch.Size([2, 36])
# Graph 491 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 492 - x shape: torch.Size([25, 45]), edge_index shape: torch.Size([2, 48])
# Graph 493 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 494 - x shape: torch.Size([14, 45]), edge_index shape: torch.Size([2, 26])
# Graph 495 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 496 - x shape: torch.Size([13, 45]), edge_index shape: torch.Size([2, 24])
# Graph 497 - x shape: torch.Size([17, 45]), edge_index shape: torch.Size([2, 32])
# Graph 498 - x shape: torch.Size([25, 45]), edge_index shape: torch.Size([2, 48])
# Graph 499 - x shape: torch.Size([3, 45]), edge_index shape: torch.Size([2, 4])
# Graph 500 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 501 - x shape: torch.Size([14, 45]), edge_index shape: torch.Size([2, 26])
# Graph 502 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 503 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 504 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 505 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 506 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 507 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 508 - x shape: torch.Size([13, 45]), edge_index shape: torch.Size([2, 24])
# Graph 509 - x shape: torch.Size([14, 45]), edge_index shape: torch.Size([2, 26])
# Graph 510 - x shape: torch.Size([13, 45]), edge_index shape: torch.Size([2, 24])
# Graph 511 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 512 - x shape: torch.Size([12, 45]), edge_index shape: torch.Size([2, 22])
# Graph 513 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 514 - x shape: torch.Size([13, 45]), edge_index shape: torch.Size([2, 24])
# Graph 515 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 516 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 517 - x shape: torch.Size([3, 45]), edge_index shape: torch.Size([2, 4])
# Graph 518 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 519 - x shape: torch.Size([7, 45]), edge_index shape: torch.Size([2, 12])
# Graph 520 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 521 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 522 - x shape: torch.Size([17, 45]), edge_index shape: torch.Size([2, 32])
# Graph 523 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 524 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 525 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 526 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 527 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 528 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 529 - x shape: torch.Size([17, 45]), edge_index shape: torch.Size([2, 32])
# Graph 530 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 531 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 532 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 533 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 534 - x shape: torch.Size([13, 45]), edge_index shape: torch.Size([2, 24])
# Graph 535 - x shape: torch.Size([9, 45]), edge_index shape: torch.Size([2, 16])
# Graph 536 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 537 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 538 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 539 - x shape: torch.Size([17, 45]), edge_index shape: torch.Size([2, 32])
# Graph 540 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 541 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 542 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 543 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 544 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 545 - x shape: torch.Size([19, 45]), edge_index shape: torch.Size([2, 36])
# Graph 546 - x shape: torch.Size([19, 45]), edge_index shape: torch.Size([2, 36])
# Graph 547 - x shape: torch.Size([21, 45]), edge_index shape: torch.Size([2, 40])
# Graph 548 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 549 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 550 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 551 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 552 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 553 - x shape: torch.Size([17, 45]), edge_index shape: torch.Size([2, 32])
# Graph 554 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 555 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 556 - x shape: torch.Size([9, 45]), edge_index shape: torch.Size([2, 16])
# Graph 557 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 558 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 559 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 560 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 561 - x shape: torch.Size([7, 45]), edge_index shape: torch.Size([2, 12])
# Graph 562 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 563 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 564 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 565 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 566 - x shape: torch.Size([7, 45]), edge_index shape: torch.Size([2, 12])
# Graph 567 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 568 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 569 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 570 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 571 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 572 - x shape: torch.Size([3, 45]), edge_index shape: torch.Size([2, 4])
# Graph 573 - x shape: torch.Size([14, 45]), edge_index shape: torch.Size([2, 26])
# Graph 574 - x shape: torch.Size([25, 45]), edge_index shape: torch.Size([2, 48])
# Graph 575 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 576 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 577 - x shape: torch.Size([17, 45]), edge_index shape: torch.Size([2, 32])
# Graph 578 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 579 - x shape: torch.Size([4, 45]), edge_index shape: torch.Size([2, 6])
# Graph 580 - x shape: torch.Size([17, 45]), edge_index shape: torch.Size([2, 32])
# Graph 581 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 582 - x shape: torch.Size([13, 45]), edge_index shape: torch.Size([2, 24])
# Graph 583 - x shape: torch.Size([19, 45]), edge_index shape: torch.Size([2, 36])
# Graph 584 - x shape: torch.Size([14, 45]), edge_index shape: torch.Size([2, 26])
# Graph 585 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# Graph 586 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 587 - x shape: torch.Size([16, 45]), edge_index shape: torch.Size([2, 30])
# Graph 588 - x shape: torch.Size([7, 45]), edge_index shape: torch.Size([2, 12])
# Graph 589 - x shape: torch.Size([14, 45]), edge_index shape: torch.Size([2, 26])
# Graph 590 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 591 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 592 - x shape: torch.Size([19, 45]), edge_index shape: torch.Size([2, 36])
# Graph 593 - x shape: torch.Size([9, 45]), edge_index shape: torch.Size([2, 16])
# Graph 594 - x shape: torch.Size([17, 45]), edge_index shape: torch.Size([2, 32])
# Graph 595 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 596 - x shape: torch.Size([7, 45]), edge_index shape: torch.Size([2, 12])
# Graph 597 - x shape: torch.Size([11, 45]), edge_index shape: torch.Size([2, 20])
# ...
# Graph 2287 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 2288 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 2289 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 2290 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 2291 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 2292 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 2293 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 2294 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2295 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2296 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2297 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2298 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2299 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2300 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2301 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2302 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2303 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2304 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2305 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2306 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2307 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2308 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2309 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2310 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2311 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2312 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2313 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2314 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2315 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2316 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2317 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2318 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2319 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2320 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2321 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2322 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2323 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2324 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2325 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2326 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2327 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2328 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2329 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2330 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2331 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2332 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2333 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2334 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2335 - x shape: torch.Size([6, 45]), edge_index shape: torch.Size([2, 10])
# Graph 2336 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2337 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2338 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2339 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2340 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2341 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2342 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2343 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2344 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2345 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2346 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2347 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2348 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2349 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2350 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2351 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2352 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2353 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2354 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2355 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2356 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2357 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2358 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2359 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2360 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2361 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2362 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2363 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2364 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2365 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2366 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2367 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2368 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2369 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2370 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2371 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2372 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2373 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 2374 - x shape: torch.Size([2, 45]), edge_index shape: torch.Size([2, 2])
# Graph 2375 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2376 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2377 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2378 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2379 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2380 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2381 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2382 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2383 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2384 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2385 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2386 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2387 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2388 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2389 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2390 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2391 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2392 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2393 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2394 - x shape: torch.Size([5, 45]), edge_index shape: torch.Size([2, 8])
# Graph 2395 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2396 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2397 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2398 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2399 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2400 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2401 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2402 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2403 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2404 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2405 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2406 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2407 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2408 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2409 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2410 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2411 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2412 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2413 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2414 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2415 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2416 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2417 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2418 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2419 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2420 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2421 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2422 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2423 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2424 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2425 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2426 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2427 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2428 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2429 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2430 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2431 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2432 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2433 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2434 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2435 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2436 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2437 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2438 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2439 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2440 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2441 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2442 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2443 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2444 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2445 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2446 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2447 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2448 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2449 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2450 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2451 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2452 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2453 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2454 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2455 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2456 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2457 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2458 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2459 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2460 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2461 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2462 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2463 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2464 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2465 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2466 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2467 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2468 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2469 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2470 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2471 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2472 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2473 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2474 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2475 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2476 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2477 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2478 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2479 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2480 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2481 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2482 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])
# Graph 2483 - x shape: torch.Size([8, 45]), edge_index shape: torch.Size([2, 14])

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
train_data, test_data = train_test_split(batch, test_size=0.25, random_state=42)
val_data, test_data = train_test_split(test_data, test_size=0.1, random_state=42)

# %%
train_batch = Batch.from_data_list(train_data)
val_batch = Batch.from_data_list(val_data)
test_batch = Batch.from_data_list(test_data)

# %%
# # Initialize and train model
num_node_features = batch.num_node_features
model = GNN(num_node_features)

# # Train the model
train_model(model, train_batch, 200)

accuracy = test_model(model, val_batch)
print(f'Val Accuracy: {accuracy:.4f}')

# # Evaluate the model
accuracy = test_model(model, test_batch)
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch: 0, Loss: 1.1400, Accuracy: 0.5341
# Epoch: 10, Loss: 0.8462, Accuracy: 0.5700
# Epoch: 20, Loss: 0.6952, Accuracy: 0.5293
# Epoch: 30, Loss: 0.6862, Accuracy: 0.5378
# Epoch: 40, Loss: 0.6737, Accuracy: 0.5722
# Epoch: 50, Loss: 0.6628, Accuracy: 0.6039
# Epoch: 60, Loss: 0.6390, Accuracy: 0.5813
# Epoch: 70, Loss: 0.6190, Accuracy: 0.6801
# Epoch: 80, Loss: 0.5757, Accuracy: 0.6420
# Epoch: 90, Loss: 0.5513, Accuracy: 0.6522
# Epoch: 100, Loss: 0.5627, Accuracy: 0.7348
# Epoch: 110, Loss: 0.5028, Accuracy: 0.7483
# Epoch: 120, Loss: 0.4691, Accuracy: 0.6500
# Epoch: 130, Loss: 0.4573, Accuracy: 0.7697
# Epoch: 140, Loss: 0.4955, Accuracy: 0.7907
# Epoch: 150, Loss: 0.4270, Accuracy: 0.7789
# Epoch: 160, Loss: 0.4292, Accuracy: 0.7955
# Epoch: 170, Loss: 0.4166, Accuracy: 0.8218
# Epoch: 180, Loss: 0.4194, Accuracy: 0.8288
# Epoch: 190, Loss: 0.4289, Accuracy: 0.7842
# Test Accuracy: 0.7742
# Test Accuracy: 0.7778
